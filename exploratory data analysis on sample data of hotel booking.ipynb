# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
#
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# # => Importing Essential Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Set maximum columns to be display in datafram as 35

pd.set_option("display.max_columns", 35)

# %% [markdown]
# # => Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # => csv file location

# %%
file_loc='/content/drive/MyDrive/eda hotel booking/Hotel Bookings (1).csv'

# %% [markdown]
# # => Reading data

# %%
df=pd.read_csv(file_loc)

# %% [markdown]
# # => Data Exploration
#
#    (checking  size and printing first 5 and last 5 element of the list)

# %%
print(f'we have  {df.shape[0]} shape and {df.shape[1]} rows')
# Out:
# we have  119390 shape and 32 rows

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# now look at describe method to get insight of data

df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# now look at data with non null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Data Description:
#
#
# hotel : Hotel(Resort Hotel or City Hotel)
#
# is_canceled : Value indicating if the booking was canceled (1) or not (0)
#
# lead_time :* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# arrival_date_year : Year of arrival date
#
# arrival_date_month : Month of arrival date
#
# arrival_date_week_number : Week number of year for arrival date
#
# arrival_date_day_of_month : Day of arrival date
#
# stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# stays_in_week_nights : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# adults : Number of adults
#
# children : Number of children
#
# babies : Number of babies
#
# meal : Type of meal booked. Categories are presented in standard hospitality meal packages:
#
# country : Country of origin.`
#
# market_segment : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# distribution_channel : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# is_repeated_guest : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
#
# reserved_room_type : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# assigned_room_type : Code for the type of room assigned to the booking.
#
# booking_changes : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# deposit_type : Indication on if the customer made a deposit to guarantee the booking.
#
# agent : ID of the travel agency that made the booking
#
# company : ID of the company/entity that made the booking or responsible for paying the booking.
#
# days_in_waiting_list : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# customer_type : Type of booking, assuming one of four categories
#
# adr : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# required_car_parking_spaces : Number of car parking spaces required by the customer
#
# total_of_special_requests :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# reservation_status : Reservation last status, assuming one of three categories
#
# Canceled – booking was canceled by the customer
#
# Check-Out – customer has checked in but already departed
#
# No-Show – customer did not check-in and did inform the hotel of the reason why
#
# reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %%
# => now create a copy of data set and print all the columns name
df_1= df.copy()
print(list(df_1.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
df_1.shape
# Out:
# (119390, 32)

# %% [markdown]
# # => Data cleaning

# %%
# check for duplicate rows here true means duplicate rows

df_1.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
#visualize same data

plt.figure(figsize=(10,10))
sns.countplot(x=df_1.duplicated())
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Here we can see that we have total 31994 duplicate row

# %%
## now we need to remove the duplicate rows

df_1 = df_1.drop_duplicates()

# %%
# now check the size of dataframe

df_1.shape
# Out:
# (87396, 32)

# %% [markdown]
# # => Now check for null values and remove them

# %%
df_1.isna().sum().sort_values(ascending= False).reset_index().rename(columns={'index':'column', 0:'null_values'})
# Out:
#                             column  null_values
# 0                          company        82137
# 1                            agent        12193
# 2                          country          452
# 3                         children            4
# 4               reserved_room_type            0
# 5               assigned_room_type            0
# 6                  booking_changes            0
# 7                     deposit_type            0
# 8                            hotel            0
# 9           previous_cancellations            0
# 10            days_in_waiting_list            0
# 11                   customer_type            0
# 12                             adr            0
# 13     required_car_parking_spaces            0
# 14       total_of_special_requests            0
# 15              reservation_status            0
# 16  previous_bookings_not_canceled            0
# 17               is_repeated_guest            0
# 18                     is_canceled            0
# ...

# %% [markdown]
# # We have null values in only 4 columns
#  company
#  agent
#  country
#  children since company agent children all have data type float 64 we can replace na with 0 and since country is object type we will replace na in country column by others

# %%
na_columns=['company','agent','children']
for item in na_columns:
  df_1[item].fillna(0, inplace=True)

# %%
df_1['country'].fillna('others',inplace=True)

# %% [markdown]
# # Check for null values again

# %%
df_1.isna().sum()         #no null values left
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# dropping all the rows where count of adults ,childrens , babies are equal to 0

len(df_1[df_1['adults']+df_1['children']+df_1['babies']==0])
# Out:
# 166

# %%
df_1.drop(df_1[df_1['adults']+df_1['children']+df_1['babies']==0].index,inplace=True)

# %% [markdown]
# # Now add some new column like total people and total stay

# %%
df_1['total_people']=df_1['adults']+df_1['babies']+df_1['children']

# %%
df_1['total_stay']=df_1['stays_in_week_nights']+df_1['stays_in_weekend_nights']

# %%
df_1.columns                                  # here we can see 2 more columns are added
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'total_people',
#        'total_stay'],
#       dtype='object')

# %% [markdown]
# # EDA

# %% [markdown]
# # 1) which type of hotel is most preffered by guest

# %%
# visualization of most preferred hotel

df_1['hotel'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,10),fontsize=15)
plt.title('Most preferred hotel ')
# Out:
# Text(0.5, 1.0, 'Most preferred hotel ')

# %% [markdown]
# # Conclusion: city hotel is most preferred hotel by guests

# %% [markdown]
# # 2) which agent made most of the bookings

# %%
highest_booking= df_1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'counts':"Most_booking"}).sort_values(by='count',ascending=False)
# taking  top 15 agents

top_agents=highest_booking[:15]
top_agents
# Out:
#      agent  count
# 9      9.0  28721
# 174  240.0  13028
# 0      0.0  12141
# 14    14.0   3342
# 7      7.0   3294
# 183  250.0   2779
# 175  241.0   1644
# 27    28.0   1493
# 8      8.0   1383
# 1      1.0   1228
# 6      6.0   1117
# 39    40.0    986
# 228  314.0    844
# 176  242.0    722
# 73    83.0    614

# %%
plt.figure(figsize=(18,8))
sns.barplot(x=top_agents['agent'],y=top_agents['count'],order=top_agents['agent'])
plt.xlabel('agent id number')
plt.ylabel('count of booking')
plt.title('most booking made by agent')
# Out:
# Text(0.5, 1.0, 'most booking made by agent')

# %% [markdown]
# ## Agent with id 9.0 made the highest bookings

# %% [markdown]
# # 3) what is the percentage of cancellation ?

# %%
from seaborn._core.properties import FontSize
df_1['is_canceled'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,10),fontsize=10)
plt.title('cancellation and non cancellation')
# Out:
# Text(0.5, 1.0, 'cancellation and non cancellation')

# %% [markdown]
# # Conclusion 3:  72.5% booking were not cancelled while 27.5 % booking were cancelled

# %% [markdown]
# #4) What is the percentage of repeated guests?

# %%
df_1['is_repeated_guest'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(10,10),fontsize=10)
plt.title('repeated guest')
# Out:
# Text(0.5, 1.0, 'repeated guest')

# %% [markdown]
# # Conclusion 4 : only 3.9% customer repeated their booking

# %% [markdown]
# # 5) What is the percentage distribution of customer type ?

# %%
df_1['customer_type'].value_counts()
# Out:
# Transient          71862
# Transient-Party    11692
# Contract            3135
# Group                541
# Name: customer_type, dtype: int64

# %%
df_1['customer_type'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,10),fontsize=10)
labels=df_1['customer_type'].value_counts().index.tolist()
plt.title('different type of customer distribution ')
plt.legend(loc='upper left',labels=labels)

# %% [markdown]
# # Observation 5) transient type customer were most among different type 82.4% while customer associated with group are least only 0.6%

# %% [markdown]
# # 6) what is the percentage distribution of car parking requirment??

# %%
df_1['required_car_parking_spaces'].value_counts()
# Out:
# 0    79924
# 1     7273
# 2       28
# 3        3
# 8        2
# Name: required_car_parking_spaces, dtype: int64

# %%
# visual representation of same data

df_1['required_car_parking_spaces'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,10),fontsize=10)
labels=df_1['required_car_parking_spaces'].value_counts()
plt.title('car parking requirment distribution')
plt.legend(loc='upper left',labels=labels)

# %% [markdown]
# # observation 6) 91.6% of guests didnot require parking space which is almost 80000 customer and 8.3% which is equal to 7200+ require single parking space

# %% [markdown]
# # 7) What is the percentage of booking changes made by the customer?

# %%
booking_changes_df=df_1['booking_changes'].value_counts().reset_index().rename(columns={'index':'number_booking_changes','booking_changes':'counts'})
plt.figure(figsize=(10,10))
sns.barplot(x=booking_changes_df['number_booking_changes'],y=booking_changes_df['counts']*100/df_1.shape[0])
plt.title('% of booking change')
plt.xlabel('number of booking changes')
plt.ylabel('percentage(%)')
# Out:
# Text(0, 0.5, 'percentage(%)')

# %% [markdown]
# # Conclusion 7)  Almost 82 percent of booking were not changed by guests

# %% [markdown]
# # 8) what is the percentage distribution of deposit type ?

# %%
df_1['deposit_type'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,10),fontsize=10)
plt.title('%distribution of deposit type')
labels=df_1['deposit_type'].value_counts().index.tolist()
plt.legend(loc='upper left',labels=labels)

# %% [markdown]
# # Conclusion 8)=> 98.7% of guest prefer no deposit while booking hotel

# %% [markdown]
# # 9) Which type of food is mostly preferred by the guests ?

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df_1['meal'])
plt.xlabel('meal type')
plt.ylabel('count')
plt.title('preffered meal type')
# Out:
# Text(0.5, 1.0, 'preffered meal type')

# %% [markdown]
# # conclusion 9)=> there are 4 main category of food and an undefined type
# bb= bed and breakfast,
# hb=half board,
# fb= full board,
# sc= self catering
#
# most of the customer preferred bed and breakfast (bb)

# %% [markdown]
# # 10) from which country the most guests are coming?

# %%
country_df=df_1['country'].value_counts().reset_index().rename(columns={'index':'country','country':'count of guests'})[:7]
plt.figure(figsize=(15,10))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('country')
plt.ylabel('number of guests')
plt.title("number of guest from different country")
# Out:
# Text(0.5, 1.0, 'number of guest from different country')

# %% [markdown]
# # conclusion 10)=> here we have plot a graph to show 7 top countries with max booking
#
# prt= pourtgal has max booking followed by united kingdom, france, spain and so on

# %% [markdown]
# # 11) which is the most preferreed room type by the customer?

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df_1['assigned_room_type'],order=df_1['assigned_room_type'].value_counts().index)
plt.xlabel('Room Type')
plt.ylabel('count')
plt.title('most preferred room')
# Out:
# Text(0.5, 1.0, 'most preferred room')

# %% [markdown]
# # conclusion 11) most preferred room type is 'A' then 'D' and so on

# %% [markdown]
# # 12) In which month most of the booking happened?

# %%
booking_months_df=df_1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':'counts'})
months=['January','February','March','April','May','June','July','August','September','October','November','December']
booking_months_df['arrival_date_month']=pd.Categorical(booking_months_df['arrival_date_month'],categories= months,ordered=True)
booking_months_df=booking_months_df.sort_values('arrival_date_month')

booking_months_df
# Out:
#    arrival_date_month  counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=booking_months_df['arrival_date_month'],y=booking_months_df['counts'])
plt.title('number of booking across each month' )
plt.xlabel('month')
plt.ylabel('number of bookings')
# Out:
# Text(0, 0.5, 'number of bookings')

# %% [markdown]
# # Conclusion 12) august month had seen most number of booking.

# %% [markdown]
# # 13) which distribution channel is mostly used for hotel bookings ?

# %%
labels=df_1['distribution_channel'].value_counts().index.tolist()
distribution_channel_df=df_1['distribution_channel'].value_counts().reset_index().rename(columns={'index':'distribution_channel','distribution_channel':'count'})
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df_1.shape[0],1)
sizes=distribution_channel_df['percentage'].values.tolist()

# plotting pie chart
df_1['distribution_channel'].value_counts().plot.pie(figsize=(10,10),fontsize=10)
labels=[f'{l},{s}%' for l,s in zip (labels,sizes)]
plt.legend(loc='upper left',labels=labels)
plt.title('most used distribution channel for booking')
# Out:
# Text(0.5, 1.0, 'most used distribution channel for booking')

# %% [markdown]
# # most used channel for booking is TA/TO

# %% [markdown]
# # 14) which hotel type has the highest ADR(average daily rate)

# %%
# group by hotel

group_by_hotel=df_1.groupby('hotel')
highest_adr=group_by_hotel['adr'].mean().reset_index()
plt.figure(figsize=(10,10))
plt.xlabel('hotel type')
plt.ylabel('adr')
plt.title("avg adr of each hotel type")
sns.barplot(x=highest_adr['hotel'], y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'avg adr of each hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# # observation 14)=> city hotels has more adr compared to resort hotels

# %% [markdown]
# # 15) which hotel has more lead time?

# %%
avg_lead_time=group_by_hotel['lead_time'].mean().reset_index()
plt.figure(figsize=(10,10))
sns.barplot(x=avg_lead_time['hotel'],y=avg_lead_time['lead_time'])

plt.xlabel('hotel type')
plt.ylabel('average lead time')
plt.title('average lead time for each hotel type')
# Out:
# Text(0.5, 1.0, 'average lead time for each hotel type')

# %% [markdown]
# # Observation 15) resort hotels have slightly high avg lead time that means customers plan their trips very early

# %% [markdown]
# # 16) which hotel has highest percentage of booking cancellation?

# %%
cancelled_df=df_1[df_1['is_canceled']==1 ]
cancelled_df=cancelled_df.groupby('hotel').size().reset_index().rename(columns={0:'no_of_cancelled_bookings'})
cancelled_df['total_bookings']=df_1.groupby('hotel').size().reset_index().rename(columns={0:'total_bookings'}).drop('hotel',axis=1)
cancelled_df
# Out:
#           hotel  no_of_cancelled_bookings  total_bookings
# 0    City Hotel                     16035           53274
# 1  Resort Hotel                      7974           33956

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=cancelled_df['hotel'], y=cancelled_df['no_of_cancelled_bookings']*100/ cancelled_df['total_bookings'])
# Out:
# <Axes: xlabel='hotel'>

# %% [markdown]
# # conclusion 16) city hotel has more cancellation percentage as compared to resort hotels

# %% [markdown]
# # 17) which hotel has most repeated guests??

# %%
repeated_guest_df= df_1[df_1['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number of repeated guests'})
repeated_guest_df
# Out:
#           hotel  number of repeated guests
# 0    City Hotel                       1657
# 1  Resort Hotel                       1707

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=repeated_guest_df['hotel'],y=repeated_guest_df['number of repeated guests'])

plt.xlabel('hotel type')
plt.ylabel('count of repeated guests')
plt.title('most repeated guest at each hotel')
# Out:
# Text(0.5, 1.0, 'most repeated guest at each hotel')

# %% [markdown]
# # Observation 17) resort hotel has slightly more repeated guest.

# %% [markdown]
# # 18) what is ADR across the different months?

# %%
booking_months_df=df_1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
booking_months_df['arrival_date_month']=pd.Categorical(booking_months_df['arrival_date_month'],categories=months,ordered=True)
booking_months_df=booking_months_df.sort_values('arrival_date_month')
booking_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.193911
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x=booking_months_df['arrival_date_month'],y=booking_months_df['adr'],hue=booking_months_df['hotel'])
plt.title('ADR across each month')
plt.xlabel('month')
plt.ylabel('adr')
# Out:
# Text(0, 0.5, 'adr')

# %% [markdown]
# # observation 18) for resort hotel adr is high in the months june,july,august as compared to city hotel. May be guests want to spend their summer holidays in resort hotels

# %% [markdown]
# # 19) which distribution channel contribute more to adr in order to increase the income ?

# %%
distribution_channel_df=df_1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x='distribution_channel',y='adr',data=distribution_channel_df,hue='hotel')
plt.title('ADR across distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across distribution channel')

# %% [markdown]
# # Observation 19) Direct and TA/TO has almost equally contributed in adr in both type of hotel
#
# # gds has highly contributed in city hotel

# %% [markdown]
# # 20) Does the guests alloted with the same roomtype which was reserved by them?

# %%
def same_room_allotment(x):
  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

# %%
df_1['same_room_allocated_or_not']=df_1.apply(lambda x: same_room_allotment(x),axis=1)
grp_by_cancelled_df=df_1.groupby('is_canceled')
DF=pd.DataFrame(grp_by_cancelled_df['same_room_allocated_or_not'].sum()*100/grp_by_cancelled_df.size()).rename(columns={0:'percentage'})
DF
# Out:
#              percentage
# is_canceled
# 0             19.572610
# 1              2.565705

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=DF.index, y=DF['percentage'])

plt.title('% of not getting the same room vs booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting the same room as per reservation')
plt.xticks([0,1],['not canceled','canceled'])
# Out:
# ([<matplotlib.axis.XTick at 0x7d4f416dd5a0>,
# ...
#  [Text(0, 0, 'not canceled'), Text(1, 0, 'canceled')])

# %% [markdown]
# # Observation 20) its clear that there is not much effect on cancellation of the booking even if the guests are not assisgned with the room they booked.

# %% [markdown]
# # Conclusion=>

# %% [markdown]
# 1) City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
#
# 2) 27.5 % bookings were got cancelled out of all the bookings.
#  Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
#
# 3)The percentage of 0 changes made in the booking was more than 82 %. Percentage of Single changes made was about 10%.
#
# 4)Most of the customers (91.6%) do not require car parking spaces.
#
# 5) 79.1 % bookings were made through TA/TO (travel agents/Tour operators).
#
# 6)BB( Bed & Breakfast) is the most preferred type of meal by the guests.
#
# 7)Maximum number of guests were from Portugal, i.e. more than 25000 guests.
#
# 8)Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
#
# 9)Booking cancellation rate is high for City hotels which almost 30 %.
#
# 10)Average lead time for resort hotel is high.
#
# 11)Waiting time period for City hotel is high as compared to resort hotels.
#  That means city hotels are much busier than Resort hotels.
#
# 12)Resort hotels have the most repeated guests.
